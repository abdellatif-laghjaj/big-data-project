# %%
import cv2
import numpy as np
from scipy.signal import fftconvolve
from skimage import color, data, restoration
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter

# %%
image = Image.open('image.png')

# Reduce blur by applying a sharpening filter
sharpened_image = image.filter(ImageFilter.SHARPEN)
plt.subplot(121), plt.imshow(image), plt.title('Original')
plt.subplot(122), plt.imshow(sharpened_image), plt.title('Sharpened')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 9
#       7 plt.show()
#       8 # Apply Gaussian blur
# ----> 9 blurred_image = cv2.GaussianBlur(np.array(image), (10, 10), 0)
#      10 plt.subplot(121), plt.imshow(image), plt.title('Original')
#      11 plt.subplot(122), plt.imshow(blurred_image), plt.title('Blurred')
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\smooth.dispatch.cpp:294: error: (-215:Assertion failed) ksize.width > 0 && ksize.width % 2 == 1 && ksize.height > 0 && ksize.height % 2 == 1 in function 'cv::createGaussianKernels'
